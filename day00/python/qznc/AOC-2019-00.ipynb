# %% [markdown]
# # Day 00
#
# The traditional start in a new project is a Hello World program.
# In this case, the challenge is get Jupyter running on [gitpod.io](https.//gitpod.io).

# %%
print("Hello Advent of Code!")
# Out:
# Hello Advent of Code!
